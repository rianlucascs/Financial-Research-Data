# %% [markdown]
# # Cálculo do Drawdown Atual - Grupo de Ativos
#
# Calcula o drawdown atual de cada ativo e armazena em um DataFrame.

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
tickers = [
    "ABEV3.SA", "ALOS3.SA", "AXIA6.SA", "B3SA3.SA", "BBDC3.SA", "BBDC4.SA",
    "BPAC11.SA", "BRAP4.SA", "BRAV3.SA", "CPFE3.SA", "CPLE3.SA", "CURY3.SA",
    "EGIE3.SA", "EMBJ3.SA", "ENEV3.SA", "ENGI11.SA", "EQTL3.SA", "FLRY3.SA",
    "GGBR4.SA", "GOAU4.SA", "IGTI11.SA", "IRBR3.SA", "ISAE4.SA", "ITSA4.SA",
    "ITUB4.SA", "KLBN11.SA", "MOTV3.SA", "MRVE3.SA", "MULT3.SA", "PRIO3.SA",
    "PSSA3.SA", "RADL3.SA", "RENT3.SA", "SANB11.SA", "SBSP3.SA", "SLCE3.SA",
    "SUZB3.SA", "TAEE11.SA", "TIMS3.SA", "UGPA3.SA", "USIM5.SA", "VALE3.SA",
    "VBBR3.SA", "VIVT3.SA", "WEGE3.SA",

    '^BVSP'
]

# %%
# Baixar dados históricos
print("Baixando dados...")
data = yf.download(tickers, period="5y", progress=False)['Close']
print(f"✓ {data.shape[0]} dias, {data.shape[1]} ativos")
# Out:
# Baixando dados...
# ✓ 1248 dias, 46 ativos

# %%
# Calcular o drawdown atual de cada ativo
drawdown_atual = []

for ticker in data.columns:
    prices = data[ticker].dropna()
    
    # Máximo histórico
    max_price = prices.max()
    
    # Preço atual (último)
    current_price = prices.iloc[-1]
    
    # Drawdown atual = (preço_atual - máximo) / máximo * 100
    dd = ((current_price - max_price) / max_price) * 100
    
    drawdown_atual.append(dd)

# Criar DataFrame com os tickers e o drawdown atual
df = pd.DataFrame({
    'Ticker': data.columns,
    'Drawdown_Atual_%': drawdown_atual
})

# Ordenar do pior para o melhor
df = df.sort_values('Drawdown_Atual_%').reset_index(drop=True)

df
# Out:
#        Ticker  Drawdown_Atual_%
# 0    USIM5.SA        -66.317491
# 1    BRAV3.SA        -63.340481
# 2    IRBR3.SA        -61.782047
# 3    MRVE3.SA        -40.572593
# 4    RENT3.SA        -19.737788
# 5    SLCE3.SA        -15.473467
# 6    SUZB3.SA        -15.135896
# 7    GGBR4.SA        -11.462281
# 8    FLRY3.SA        -10.845881
# 9    GOAU4.SA        -10.161441
# 10   RADL3.SA         -9.381887
# 11   EMBJ3.SA         -9.330509
# 12   CPFE3.SA         -7.940539
# 13  SANB11.SA         -6.880005
# 14   WEGE3.SA         -6.727429
# 15   PSSA3.SA         -6.256595
# 16  KLBN11.SA         -4.336315
# 17   CURY3.SA         -3.839689
# 18   ITUB4.SA         -3.807975
# 19   BRAP4.SA         -2.965599
# 20  BPAC11.SA         -2.828676
# 21   VBBR3.SA         -2.753439
# 22   ITSA4.SA         -2.388850
# 23   VALE3.SA         -2.175601
# 24   MOTV3.SA         -2.149907
# 25   BBDC4.SA         -1.884190
# 26   TIMS3.SA         -1.626020
# 27   EGIE3.SA         -1.544183
# 28   ISAE4.SA         -1.121743
# 29   BBDC3.SA         -1.120593
# 30   ENEV3.SA         -1.111605
# 31   PRIO3.SA         -0.981463
# 32   SBSP3.SA         -0.703447
# 33   ABEV3.SA         -0.484261
# 34   UGPA3.SA         -0.467966
# 35   B3SA3.SA          0.000000
# 36   AXIA6.SA          0.000000
# 37   ALOS3.SA          0.000000
# 38   CPLE3.SA          0.000000
# 39  ENGI11.SA          0.000000
# 40   MULT3.SA          0.000000
# 41  IGTI11.SA          0.000000
# 42   EQTL3.SA          0.000000
# 43  TAEE11.SA          0.000000
# 44   VIVT3.SA          0.000000
# 45      ^BVSP          0.000000
